# %%
# Library imports

import pandas as pd

# %%
# Read large dataset
songs = pd.read_csv('spotify_full.csv')

# %%
len(songs)
# Out:
# 114000

# %%
songs
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
songs.iloc[3]
# Out:
# Unnamed: 0                                                          3
# track_id                                       6lfxq3CG4xtTiEg7opyCyx
# artists                                                  Kina Grannis
# album_name          Crazy Rich Asians (Original Motion Picture Sou...
# track_name                                 Can't Help Falling In Love
# popularity                                                         71
# duration_ms                                                    201933
# explicit                                                        False
# danceability                                                    0.266
# energy                                                         0.0596
# key                                                                 0
# loudness                                                      -18.515
# mode                                                                1
# ...

# %%
# Sample 5 songs

five = songs.sample(n=5)
five
# Out:
#         Unnamed: 0                track_id            artists  \
# 108488      108488  1j2y95K4ZTmmDJEHBYWcwo       Tita Merello
# 25474        25474  0aNzTtCyoLhlXtATP7bcHh      Markus Becker
# 22925        22925  0v3WyEt2g04WFpfVwcnfXm         Candlemass
# 8861          8861  2pcwmk8c1pTYwX0COSVX52         Wolfmother
# 19900        19900  2PGYNCB7e3bC7AP0WMJiUI  Music Travel Love
#
#                                     album_name  \
# 108488                            Serie De Oro
# 25474                    Nano (vom Planeten X)
# 22925               Epicus Doomicus Metallicus
# 8861                                Wolfmother
# 19900   Take Me Home, Country Roads (Acoustic)
#
#                                     track_name  popularity  duration_ms  \
# 108488                               Niño Bien          19       130066
# 25474                    Nano (vom Planeten X)          33       190750
# 22925                                 Solitude          49       338440
# ...

# %%
# Specify a random seed to sample the same five songs
five = songs.sample(n=5, random_state=123)
five
# Out:
#        Unnamed: 0                track_id                        artists  \
# 76250       76250  5hShhnAwyvAW4BigMd1r5h  Andrea Bocelli;Jennifer Lopez
# 36340       36340  0Ord8zDs9Kwa01AT5OkbcY               Tiken Jah Fakoly
# 19932       19932  1JswREP8dKSYnAgGcDx2TP                     Avery Anna
# 65784       65784  7cMKz5MoUTPH2N4yqpAUAO    Anuradha Paudwal;Kumar Sanu
# 49937       49937  3CC06i76ZKONH9dmC6dqTP                       Szeukers
#
#                                               album_name  \
# 76250                                  Love In Portofino
# 36340                                Africa Rising Vol.1
# 19932                        Never Leave - Country Magic
# 65784  Ultimate Romantic Duet - Kumar Sanu & Anuradha...
# 49937                                          Op De Hei
#
#                                   track_name  popularity  duration_ms  \
# 76250                 Quizás, Quizás, Quizás          51       198455
# ...

# %%
# Alternatively, specify a FRACTION of songs to be sampled
sample_1pct = songs.sample(frac=0.01)
len(sample_1pct)
# Out:
# 1140

# %%
# replace:  False (default): Same song can't be picked twice.   

repeats = five.sample(n=5, replace=True)
repeats
# Out:
#        Unnamed: 0                track_id                        artists  \
# 65784       65784  7cMKz5MoUTPH2N4yqpAUAO    Anuradha Paudwal;Kumar Sanu
# 76250       76250  5hShhnAwyvAW4BigMd1r5h  Andrea Bocelli;Jennifer Lopez
# 76250       76250  5hShhnAwyvAW4BigMd1r5h  Andrea Bocelli;Jennifer Lopez
# 65784       65784  7cMKz5MoUTPH2N4yqpAUAO    Anuradha Paudwal;Kumar Sanu
# 19932       19932  1JswREP8dKSYnAgGcDx2TP                     Avery Anna
#
#                                               album_name  \
# 65784  Ultimate Romantic Duet - Kumar Sanu & Anuradha...
# 76250                                  Love In Portofino
# 76250                                  Love In Portofino
# 65784  Ultimate Romantic Duet - Kumar Sanu & Anuradha...
# 19932                        Never Leave - Country Magic
#
#                                   track_name  popularity  duration_ms  \
# 65784  Tu Meri Zindagi Hai (From "Aashiqui")          47       285280
# ...

# %%
# The canonical way to shuffle rows in a dataframe
# Something we'll want to do when creating training and test sets

shuffled = songs.sample(frac=1)
shuffled
# Out:
#        Unnamed: 0                track_id  \
# 98565       98565  7fRt5HCt4KgLlH45wFQCho
# 62929       62929  4i2mHCOkZi3sZSDekVxwTj
# 85400       85400  6KWcq5p0wsz97N3eoRUSH6
# 90751       90751  2OCoH12t6olzx9bT1PEC8F
# 58482       58482  3zewJMPF5u49XQWUjJGVFI
# ...           ...                     ...
# 66885       66885  7CwXcW0wJoMdk1UVSggdkC
# 45444       45444  5EYmQ7XgC5Fxsig2SgXP2G
# 45094       45094  4wSmIPQYPWbR72mnkpyBLK
# 92925       92925  2rBXPL2zK799KQpCdAotSI
# 60705       60705  4mL32Hafo3istRKIY217tV
#
#                                                  artists  \
# 98565  Sophia Anne Caruso;Beetlejuice Original Broadw...
# 62929                                              EXILE
# 85400                                          blink-182
# 90751                                        Chuck Berry
# 58482                                               Orgy
# ...                                                  ...
# ...

# %%
# How many songs in each genre?
songs.groupby(['track_genre'])['track_genre'].count()
# Out:
# track_genre
# acoustic       1000
# afrobeat       1000
# alt-rock       1000
# alternative    1000
# ambient        1000
#                ...
# techno         1000
# trance         1000
# trip-hop       1000
# turkish        1000
# world-music    1000
# Name: track_genre, Length: 114, dtype: int64

# %%
# Lets focus on Rock, Pop, or Hip Hop.

rph = songs[songs['track_genre'].isin(['rock', 'pop', 'hip-hop'])]
print("Songs: ",len(rph))
rph = rph.sample(frac=1, ignore_index=True, random_state=314159)  # Automatically resets the index to 0, 1, 2, ....
rph.head(10)
# Out:
# Songs:  3000
#    Unnamed: 0                track_id                       artists  \
# 0       51395  5E73WRgx5QymAZBW3kbTR0    Mac Miller;Earl Sweatshirt
# 1       81277  7wNeq4RKcnjjTbEF5K9qAR                 Justin Bieber
# 2       91924  0NrXd3e8BRWhpyy9nsDQLF                 Kaiser Chiefs
# 3       51221  1dVZeuQFWzSI22d3hPEncI  Daddy Yankee;El Alfa;Lil Jon
# 4       81001  3yV2c3cYhkAwSsxAq6nRiv                Gajendra Verma
# 5       81335  3AcMDsHW30eDnGjDfiqCLS                 Justin Bieber
# 6       81406  4faDlXyZMSxEuxBdd5gDIz            AP Dhillon;Intense
# 7       81171  0Id2IzhR3w50aP2PHfMUE3                          Guri
# 8       91970  0ERQd3bFJvmuU1ofB3EYPz                          a-ha
# 9       91540  0PSKFp3zoNmJzDsOHeLV6l         The Smashing Pumpkins
#
#                                           album_name           track_name  \
# 0                                      New Rap Icons           Polo Jeans
# ...

# %%
# Create hw4 training data data
train = rph.iloc[:2000, 5:]
len(train)
train

train.to_csv('spotify_train.csv', index=False)

# %%
# Create hw4 TEST data (NOT TO BE USED FOR HYPERPARAMETER TUNING - REPORT PERFORMANCE ONLY)
# Create hw4 test data
test = rph.iloc[2000:, 5:].reset_index().iloc[:, 1:]
len(test)
test
test.to_csv('spotify_test.csv', index=False)

# %%
# Did we sample the different genres reasonably well?  Yes.
train.groupby(['track_genre'])['track_genre'].count()
# Out:
# track_genre
# hip-hop    659
# pop        668
# rock       673
# Name: track_genre, dtype: int64

# %%
test.groupby(['track_genre'])['track_genre'].count()
# Out:
# track_genre
# hip-hop    341
# pop        332
# rock       327
# Name: track_genre, dtype: int64

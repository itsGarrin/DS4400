# %% [markdown]
# Feature Summary

# %%
import pandas as pd
bc = pd.read_csv('breast_cancer.csv', header=None)
bc = bc.drop(bc.columns[0], axis=1)
bc.columns = ['thick', 'size_uni', 'shape_uni', 'marg_adh',
'size_sec', 'bare_nuc', 'bland_chromo', 'norm_chromo', 'mitosis', 'outcome']
bc
# Out:
#      thick  size_uni  shape_uni  marg_adh  size_sec bare_nuc  bland_chromo  \
# 0        5         1          1         1         2        1             3
# 1        5         4          4         5         7       10             3
# 2        3         1          1         1         2        2             3
# 3        6         8          8         1         3        4             3
# 4        4         1          1         3         2        1             3
# ..     ...       ...        ...       ...       ...      ...           ...
# 694      3         1          1         1         3        2             1
# 695      2         1          1         1         2        1             1
# 696      5        10         10         3         7        3             8
# 697      4         8          6         4         3        4            10
# 698      4         8          8         5         4        5            10
#
#      norm_chromo  mitosis  outcome
# ...

# %%
bc.describe()
# Out:
#             thick    size_uni   shape_uni    marg_adh    size_sec  \
# count  699.000000  699.000000  699.000000  699.000000  699.000000
# mean     4.417740    3.134478    3.207439    2.806867    3.216023
# std      2.815741    3.051459    2.971913    2.855379    2.214300
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000    1.000000    1.000000    1.000000    2.000000
# 50%      4.000000    1.000000    1.000000    1.000000    2.000000
# 75%      6.000000    5.000000    5.000000    4.000000    4.000000
# max     10.000000   10.000000   10.000000   10.000000   10.000000
#
#        bland_chromo  norm_chromo     mitosis     outcome
# count    699.000000   699.000000  699.000000  699.000000
# mean       3.437768     2.866953    1.589413    2.689557
# std        2.438364     3.053634    1.715078    0.951273
# min        1.000000     1.000000    1.000000    2.000000
# 25%        2.000000     1.000000    1.000000    2.000000
# ...

# %%
mal = bc[bc.outcome == 4]
ben = bc[bc.outcome == 2]

# %%
mal.describe()
# Out:
#             thick    size_uni   shape_uni    marg_adh    size_sec  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000
# mean     7.195021    6.572614    6.560166    5.547718    5.298755
# std      2.428849    2.719512    2.562045    3.210465    2.451606
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      5.000000    4.000000    4.000000    3.000000    3.000000
# 50%      8.000000    6.000000    6.000000    5.000000    5.000000
# 75%     10.000000   10.000000    9.000000    8.000000    6.000000
# max     10.000000   10.000000   10.000000   10.000000   10.000000
#
#        bland_chromo  norm_chromo     mitosis  outcome
# count    241.000000   241.000000  241.000000    241.0
# mean       5.979253     5.863071    2.589212      4.0
# std        2.273852     3.350672    2.557939      0.0
# min        1.000000     1.000000    1.000000      4.0
# 25%        4.000000     3.000000    1.000000      4.0
# ...

# %%
ben.describe()
# Out:
#             thick    size_uni   shape_uni    marg_adh    size_sec  \
# count  458.000000  458.000000  458.000000  458.000000  458.000000
# mean     2.956332    1.325328    1.443231    1.364629    2.120087
# std      1.674318    0.907694    0.997836    0.996830    0.917130
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      1.000000    1.000000    1.000000    1.000000    2.000000
# 50%      3.000000    1.000000    1.000000    1.000000    2.000000
# 75%      4.000000    1.000000    1.000000    1.000000    2.000000
# max      8.000000    9.000000    8.000000   10.000000   10.000000
#
#        bland_chromo  norm_chromo     mitosis  outcome
# count    458.000000   458.000000  458.000000    458.0
# mean       2.100437     1.290393    1.063319      2.0
# std        1.080339     1.058856    0.501995      0.0
# min        1.000000     1.000000    1.000000      2.0
# 25%        1.000000     1.000000    1.000000      2.0
# ...

# %%
mal.describe().loc[['mean', 'std']]
# Out:
#          thick  size_uni  shape_uni  marg_adh  size_sec  bland_chromo  \
# mean  7.195021  6.572614   6.560166  5.547718  5.298755      5.979253
# std   2.428849  2.719512   2.562045  3.210465  2.451606      2.273852
#
#       norm_chromo   mitosis  outcome
# mean     5.863071  2.589212      4.0
# std      3.350672  2.557939      0.0

# %%
ben.describe().loc[['mean', 'std']]
# Out:
#          thick  size_uni  shape_uni  marg_adh  size_sec  bland_chromo  \
# mean  2.956332  1.325328   1.443231  1.364629  2.120087      2.100437
# std   1.674318  0.907694   0.997836  0.996830  0.917130      1.080339
#
#       norm_chromo   mitosis  outcome
# mean     1.290393  1.063319      2.0
# std      1.058856  0.501995      0.0

# %%
sns.histplot(data=bc, x='thick', hue='outcome')
# Out:
# <AxesSubplot: xlabel='thick', ylabel='Count'>

# %%
import seaborn as sns
sns.jointplot(data=bc, x='thick', y='size_uni', hue='outcome')

# %% [markdown]
# ### DS4400: Lab 06: Polynomial Curve Fitting

# %%
# Suppose y = mx + b + e
# That is, y responds linear with respect to x with some error

import pandas as pd
import numpy as np
#import random as rnd
import matplotlib.pyplot as plt
from sklearn import linear_model as lm

# %%
rnd = np.random.default_rng()

x1 = np.arange(0,10,.1)
y = 10 + 3*x1 + rnd.normal(0, 5, len(x1))
table = pd.DataFrame({'x1':x1, 'y':y})
table
# Out:
#      x1          y
# 0   0.0   7.627959
# 1   0.1  22.384100
# 2   0.2   9.072265
# 3   0.3  11.538215
# 4   0.4  17.853414
# ..  ...        ...
# 95  9.5  31.652389
# 96  9.6  37.842962
# 97  9.7  41.836041
# 98  9.8  37.630173
# 99  9.9  39.109665
#
# [100 rows x 2 columns]

# %%
# We'll use scikit learn to find a best fit
# Let's write a convenient reusable function


def linreg(X, y):
    regr = lm.LinearRegression()
    regr.fit(X, y)
    return [regr.intercept_] + list(regr.coef_)

b, m = linreg(table[['x1']],table.y)

# %%
plt.scatter(table.x1,table.y)
plt.xlim(0, 10)
plt.ylim(0, 40)
plt.plot([0, 10], [10,40], color='blue', label='actual')
plt.plot([0, 10], [b, b + m * 10], color='red', label='linreg')
plt.legend()
plt.grid()

# %%
# Let's make our response depend on a second attribute
# Again introducing some noise
# This time we'll generate 100 random points
# From the x1 X x2 plane
n = 100

x1 = rnd.uniform(0, 10, 100)
x2 = rnd.uniform(0, 10, 100)

B0, B1, B2 = 10, 3, -2

y = B0 + B1 * x1 + B2 * x2 + rnd.normal(0, 10, n)

table = pd.DataFrame({'x1':x1, 'x2':x2, 'y': y})
table
# Out:
#           x1        x2          y
# 0   8.195190  0.347283  34.766822
# 1   5.214441  5.999541   7.197467
# 2   9.071968  0.842792  38.389956
# 3   2.546989  5.683539   8.166520
# 4   2.897392  5.128519   3.528246
# ..       ...       ...        ...
# 95  5.505726  3.797384   8.357705
# 96  9.311576  0.826395  25.530194
# 97  6.542045  4.409429  11.446220
# 98  2.086508  9.978089 -16.604484
# 99  3.356978  7.672966  -7.818781
#
# [100 rows x 3 columns]

# %%
# How well does scikit's linear regression do? Pretty good
b0, b1, b2 = linreg(table[['x1', 'x2']], table.y)
print(b0, b1, b2)
# Out:
# 12.676031264864495 2.348479501642254 -1.9303203892961034

# %%
import plotly.graph_objects as go
import plotly.express as px

X1, X2 = np.meshgrid(x1, x2)
Yact = B0 + B1*X1 + B2*X2
Ypred = b0 + b1*X1 + b2*X2


# plot the surface plot with plotly's Surface
fig1 = go.Figure(data=go.Surface(z=Yact, x=x1, y=x2))
fig2 = go.Figure(data=go.Surface(z=Ypred, x=x1, y=x2))

fig3 = px.scatter_3d(table,  z='y', x='x1', y='x2')
fig3.update_traces(marker_size = 3)


fig = go.Figure(data = fig1.data + fig2.data + fig3.data)

fig.update_layout(
    autosize = False,
    width=1000, height=1000
)

fig.show()
# Out:
# <div>                            <div id="0212688f-d7f2-4e10-aee1-e520f0f8b39e" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0212688f-d7f2-4e10-aee1-e520f0f8b39e")) {                    Plotly.newPlot(                        "0212688f-d7f2-4e10-aee1-e520f0f8b39e",                        [{"x":[8.19518975509701,5.2144405566338135,9.071968091268683,2.5469894040926744,2.8973920760593916,4.788666703358246,2.4073797025844,0.547259545255554,5.183605726375069,6.668204173483062,1.2220358369335216,7.493321328344095,9.981698969316627,9.493122395918332,9.806235005229919,2.3629931296647513,5.000013779332417,2.850316723430101,9.700710123132492,1.7520350073720325,5.709416571106828,1.4572133425786815,0.6839307087531177,7.8427447856228705,5.240912828116654,1.5352432289171924,6.7258859240719415,1.4460753622759503,7.714777917570162,0.36746381010040685,7.040537776383058,8.367510111158404,4.0977540235993,0.8580668619645171,6.659553212890261,2.035510983853166,7.47397200693762,1.566973713018407,9.899513526301632,2.1562496282798573,0.8408603797373804,4.153890606342394,4.611501110379379,5.572375572549619,2.4031883452093696,7.598406051323496,2.6342524954019044,5.3772743196872765,6.609205591449802,5.5530369160908855,0.25258078021122565,4.3522529279530815,3.548285882841867,5.703344322505821,3.5238570337618857,1.0978231552313078,3.8997859973713367,4.982091054888691,4.001144330351694,5.392845509603515,1.1308227533068105,0.7350401996585354,2.3907942528167325,6.068359936340383,8.057955634478919,8.896279164285932,4.71787434995393,9.867787868501566,4.702835732215212,1.8571702912907317,7.007276583987228,8.036314002735454,2.601917218348796,7.196463031900676,8.811614464078806,3.7352392248795896,9.190613339600944,4.681825673370734,9.093543962005867,0.7825145873532402,1.8295228009968367,3.2214419437122754,5.6867209171774995,6.144155640718031,1.9304883321783883,1.394701526295361,9.357530929373848,0.9987962348778834,7.178477300005337,8.203890494030496,4.860051470657812,8.348725162576585,3.154128271215877,4.8545737271777885,3.2024847450444573,5.505726446653431,9.311575693880153,6.542044861622323,2.0865080130360667,3.3569779127199126],"y":[0.3472825640096566,5.999541231190858,0.84279222062831,5.683539435402359,5.128519475632228,4.858185541363518,8.553440118717797,3.2879094414448637,5.1668569280393335,9.591101482836308,0.9830399175228088,9.502301664351751,7.472491715495343,8.69800381869331,8.811529153371207,6.523616151167447,4.886446226978853,9.273434121450212,3.300158299033961,2.9514054618462806,8.419718667176548,3.552533440499456,7.440949464115306,6.445093735563708,3.7180639836977503,6.598074352941765,7.12504297298024,6.892133874326278,3.554336635972332,3.504027736217452,0.024196148722103183,3.9920743864292185,5.005118111653587,1.689925306665736,2.4629358599073337,0.6819222230124355,4.818699072039773,2.6643252740972843,2.119766361282658,3.6739270938993696,0.07501159753370956,5.830580035370141,4.898927927745724,9.718225895887599,8.535681323238265,2.5663378757886224,1.9711436451032038,8.423173556049084,6.697400577801682,2.0753827275882775,1.8542220812820465,9.399887655422098,6.527423784477525,7.499028576929342,0.9709799164541,6.303657307345711,5.343313462938871,3.195202608548544,4.297845263440953,8.620074965771904,7.513322844661792,6.57696077805785,8.114156049171156,1.5541725348735225,9.768494755890647,2.839036457954347,7.671806037761687,5.996252086972542,2.097867167338782,4.906771932858427,9.57978991131665,5.078001573435808,8.288868105698,8.310125008817874,0.6300676862341315,4.232107275609075,4.133268578346488,7.250461637040056,7.851978218124485,0.8608080361736625,6.219948279517276,0.43538414584244345,6.602319214573086,2.9751943171397865,7.149706778310904,8.379395456934194,7.998066409455121,9.524163967755575,7.390238655282952,1 ...

# %%
# Suppose we are fitting data to a polynomial???

x = np.arange(-10,10, 1)
y_act = 10 - 5*x - 4 * x**2 + .5 * x**3 
y = y_act + rnd.normal(0, 100, len(x))


table = pd.DataFrame({'x1':x, 'x2': x**2, 'x3':x**3, 'x4':x**4, 'x5':x**5, 'x6':x**6, 'x7':x**7, 'x8':x**8, 'y':y})
table
# Out:
#     x1   x2    x3     x4      x5       x6        x7         x8           y
# 0  -10  100 -1000  10000 -100000  1000000 -10000000  100000000 -848.229501
# 1   -9   81  -729   6561  -59049   531441  -4782969   43046721 -793.784342
# 2   -8   64  -512   4096  -32768   262144  -2097152   16777216 -361.437473
# 3   -7   49  -343   2401  -16807   117649   -823543    5764801 -319.903757
# 4   -6   36  -216   1296   -7776    46656   -279936    1679616 -211.864226
# 5   -5   25  -125    625   -3125    15625    -78125     390625 -309.493382
# 6   -4   16   -64    256   -1024     4096    -16384      65536  -53.667404
# 7   -3    9   -27     81    -243      729     -2187       6561  -38.938698
# 8   -2    4    -8     16     -32       64      -128        256   10.474336
# 9   -1    1    -1      1      -1        1        -1          1   58.476852
# 10   0    0     0      0       0        0         0          0  -17.122307
# 11   1    1     1      1       1        1         1          1  -79.474395
# 12   2    4     8     16      32       64       128        256  -50.741553
# 13   3    9    27     81     243      729      2187       6561   32.228142
# 14   4   16    64    256    1024     4096     16384      65536 -236.304689
# 15   5   25   125    625    3125    15625     78125     390625  -62.209330
# 16   6   36   216   1296    7776    46656    279936    1679616   22.399761
# 17   7   49   343   2401   16807   117649    823543    5764801  -98.149032
# 18   8   64   512   4096   32768   262144   2097152   16777216   34.480796
# 19   9   81   729   6561   59049   531441   4782969   43046721   41.256824

# %%
X = table[['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']]
y = table.y
B = linreg(X,y)
b0, b1, b2, b3, b4, b5, b6, b7, b8   = B
print(B)

y_pred = b0 + b1 * x + b2 * x**2 + b3 * x**3 + b4 * x**4 + b5 * x**5 + b6 * x**6 + b7 * x**7 + b8 * x**8
# Out:
# [29.604809612609387, -21.922925923887007, -19.15523873753225, 1.9342190230188192, 0.8079206656840263, -0.03291634168293148, -0.013751543293422763, 0.00023247156581529538, 7.438028656636675e-05]

# %%
# Now plot

plt.figure(figsize=(10,10))
plt.scatter(x,y, marker='.')
plt.plot(x, y_act, color='red', label='actual')
plt.plot(x, y_pred, color='blue', label='bestfit')
plt.legend()
#plt.ylim(y_act.min()-50, y_act.max()+50)

plt.grid()

# %%
def MSE(ypred, y):
    return ((ypred - y)**2 ).mean()

# %%
MSE(y, y_pred)
# Out:
# 5007.5094232381225
